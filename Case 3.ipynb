# %%
import os
import pandas as pd
import numpy as np
import math as m

# %%
os.getcwd()

# %%
case3=pd.read_csv('terror.csv',encoding="latin")
case3
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (4,61,62,66,116,117,123) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              eventid  iyear  imonth  iday           approxdate  extended  \
# 0       197000000001   1970       0     0                  NaN         0
# 1       197000000002   1970       0     0                  NaN         0
# 2       197001000001   1970       1     0                  NaN         0
# 3       197001000002   1970       1     0                  NaN         0
# 4       197001000003   1970       1     0                  NaN         0
# 5       197001010002   1970       1     1                  NaN         0
# 6       197001020001   1970       1     2                  NaN         0
# 7       197001020002   1970       1     2                  NaN         0
# ...

# %%
case3.shape

# %%
## Q.1) How many attacks happened in India?

case3[case3.country_txt=="India"][['country_txt']].count()
# Out:
# country_txt    9940
# dtype: int64

# %%
## Q.2) How many attacks happened in India and upto 3 people were killed? 

case3[(case3.country_txt=="India")&(case3.nkill<=3)][['country_txt']].count()
# Out:
# country_txt    8362
# dtype: int64

# %%
## Q.3 ) Extract the city and summary for attacks above

case3[(case3.country_txt=="India")&(case3.nkill<=3)][['summary','city','country_txt']]
# Out:
#                                                   summary               city  \
# 1185                                                  NaN          New Delhi
# 3780                                                  NaN          New Delhi
# 5251                                                  NaN             Bombay
# 7266                                                  NaN             Imphal
# 8609                                                  NaN            Unknown
# 8755                                                  NaN            Unknown
# 8977                                                  NaN             Amapur
# 9037                                                  NaN           Raisikah
# 9040                                                  NaN           Champhai
# 9070                                                  NaN             Aizawl
# 9072                                                  NaN         Jamshedpur
# ...

# %%
## Q.4) In a single terror incident in India, find out top 5 cities by number killed

case3[case3.country_txt=="India"][['city','nkill']].nlargest(5,'nkill')
# Out:
#                      city  nkill
# 81000              Mumbai  188.0
# 54339              Bombay  115.0
# 96598             Jhargam  115.0
# 95860  Dantewada district   82.0
# 56837            Banabari   70.0

# %%
## Q.5) In a single terror incident in India, find out top 5 cities by number killed and wounded 

case3[case3.country_txt=="India"][['city','nwound']].sort_values(by='nwound',ascending=False).head()
# Out:
#             city  nwound
# 81000     Mumbai   817.0
# 89128     Dispur   235.0
# 30378    Chennai   200.0
# 79045  New Delhi   155.0
# 75769     Mumbai   150.0

# %%
##Q.6 ) How many attacks were successful that were suicide attacks?

case3[(case3.suicide==1)&(case3.success==1)][['suicide']].count()
# Out:
# suicide    4260
# dtype: int64

# %%
## Q.7 ) label all the incidents where the number killed was more than 5 as severe.  
elem=[]
for i in range(0,len(case3)):
    if case3.iloc[i]['nkill'] > 5:
        elem.append('severe')
    else:
        elem.append('not severe')
case3['incidents']=elem
print(case3['incidents'].head())
# Out:
# 0    not severe
# 1    not severe
# 2    not severe
# 3    not severe
# 4    not severe
# Name: incidents, dtype: object

# %%
##  Q.8 ) write a function to label an incident that was both successful and suicidal
# def func (x): case3['inc']=np.where(case3['success']==1 and case3['suicide']==1, 'sucide successful','sucide not successful')

def catch (x) :
            x['incident_s']=['sucide successful' if (x.iloc[i]['success']==1 and x.iloc[i]['suicide']==1)  else 'sucide not successful'  for i in range(0,len(case3))]

            return (x['incidents'])        
catch(case3)
# Out:
# 0         not severe
# 1         not severe
# 2         not severe
# 3         not severe
# 4         not severe
# 5         not severe
# 6         not severe
# 7         not severe
# 8         not severe
# 9         not severe
# 10        not severe
# 11        not severe
# 12        not severe
# 13        not severe
# 14        not severe
# 15        not severe
# 16        not severe
# 17        not severe
# 18        not severe
# 19        not severe
# 20        not severe
# 21        not severe
# 22        not severe
# 23        not severe
# 24        not severe
# 25        not severe
# 26        not severe
# 27        not severe
# 28        not severe
# 29        not severe
#              ...
# 156742    not severe
# 156743    not severe
# 156744    not severe
# 156745    not severe
# 156746    not severe
# 156747    not severe
# 156748    not severe
# 156749    not severe
# 156750    not severe
# 156751    not severe
# 156752    not severe
# 156753    not severe
# ...

# %%
## Q.9) Create a new category representing if the incident occured in Afghanistan, Pakistan or India as one
#level of the category and all the other countries as another level

case3['inc_category']=['category1'if (case3.iloc[i]['country_txt']=='Pakistan'
                                       or case3.iloc[i]['country_txt']=='India'
                                       or case3.iloc[i]['country_txt']=='Afghanistan') else 'category2' for i in range(0,len(case3))]

print(case3['inc_category'].head())
# Out:
# 0    category2
# 1    category2
# 2    category2
# 3    category2
# 4    category2
# Name: inc_category, dtype: object

# %%
## Q.10) How many incidents happened in Af-Pak-India vs ROW?

Af_Pak_India=case3[(case3.inc_category=='category1')][['inc_category']].count()
Af_Pak_India
# Out:
# inc_category    32398
# dtype: int64

# %%
ROW=case3[(case3.inc_category=='category2')][['inc_category']].count()
ROW
# Out:
# inc_category    124374
# dtype: int64

# %%
## Q.11) List the number of suicides attacks and average kills by Af-Pak-India vs ROW. Rename columns in the output
#as Average_Kills and Number_Incidents.

case3.groupby('inc_category')[['suicide','nkill']].agg(['count','mean'])
# Out:
#              suicide             nkill
#                count      mean   count      mean
# inc_category
# category1      32398  0.045126   31788  2.105574
# category2     124374  0.026605  116039  2.428727
